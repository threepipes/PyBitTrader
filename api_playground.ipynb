# %%
import os
from coincheck.coincheck import CoinCheck

access_key = os.getenv('COINCHECK_API_KEY')
secret_key = os.getenv('COINCHECK_SECRET')
cc_session = CoinCheck(access_key, secret_key)

# %%
res = cc_session.ticker.all()
res
# Out:
# '{"last":1667796.0,"bid":1667198.0,"ask":1667796.0,"high":1763000.0,"low":1640000.0,"volume":24451.70360195,"timestamp":1515947903}'

# %%
type(res)
# Out:
# str

# %%
cc_session.trade.all({'pair': 'btc_jpy'})
# Out:
# '{"success":true,"pagination":{"limit":10,"order":"desc","starting_after":null,"ending_before":null},"data":[{"id":77681641,"amount":"0.04","rate":1672000,"pair":"btc_jpy","order_type":"sell","created_at":"2018-01-14T16:52:25.000Z"},{"id":77681640,"amount":"0.15","rate":1672001,"pair":"btc_jpy","order_type":"sell","created_at":"2018-01-14T16:52:25.000Z"},{"id":77681639,"amount":"0.03","rate":1672001,"pair":"btc_jpy","order_type":"sell","created_at":"2018-01-14T16:52:25.000Z"},{"id":77681638,"amount":"0.005","rate":1672001,"pair":"btc_jpy","order_type":"sell","created_at":"2018-01-14T16:52:25.000Z"},{"id":77681637,"amount":"0.1","rate":1672067,"pair":"btc_jpy","order_type":"sell","created_at":"2018-01-14T16:52:25.000Z"},{"id":77681636,"amount":"0.015","rate":1672251,"pair":"btc_jpy","order_type":"sell","created_at":"2018-01-14T16:52:25.000Z"},{"id":77681635,"amount":"0.008","rate":1672338,"pair":"btc_jpy","order_type":"buy","created_at":"2018-01-14T16:52:24.000Z"},{"id":77681634,"amou
# ...

# %%
cc_session.ticker.all()
# Out:
# '{"last":1660589.0,"bid":1660577.0,"ask":1661357.0,"high":1763000.0,"low":1640000.0,"volume":24454.33881912,"timestamp":1515948175}'

# %%
cc_session.order_book.all()
# Out:
# '{"asks":[["1663498.0","0.00198798"],["1663900.0","0.2"],["1663967.0","0.015"],["1663999.0","0.035"],["1664000.0","0.106"],["1664030.0","0.015"],["1664036.0","0.15517958"],["1664075.0","0.32"],["1664131.0","0.015"],["1664270.0","0.015"],["1664333.0","0.015"],["1664474.0","0.015"],["1664519.0","0.0181"],["1664520.0","0.05"],["1664537.0","0.015"],["1664603.0","0.1"],["1664610.0","0.02503651"],["1664793.0","0.64"],["1664900.0","0.1"],["1664930.0","0.1"],["1664987.0","0.22796075"],["1664996.0","0.0654"],["1664999.0","0.045"],["1665000.0","2.04"],["1665585.0","0.015"],["1665681.0","0.015"],["1665944.0","0.05"],["1665999.0","0.035"],["1666000.0","0.04"],["1666288.0","0.12041287"],["1666484.0","0.5"],["1666485.0","1.5"],["1666516.0","0.01814028"],["1666696.0","0.015"],["1666722.0","0.05"],["1666742.0","0.005"],["1666800.0","0.01"],["1666845.0","0.005"],["1666999.0","0.035"],["1667000.0","0.04"],["1667702.0","0.2457"],["1667703.0","11.5736"],["1667807.0","0.015"],["1667928.0","0.005"],["1667
# ...

# %%
res.json()
# Out:
# {'error': 'invalid pair', 'success': False}
