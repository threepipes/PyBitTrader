# %%
# %matplotlib inline

# %%
filepath = 'agent/result_8/scores.txt'
import pandas as pd

# %%
data = pd.read_csv(filepath, sep='\t')
data
# Out:
#       steps  episodes       elapsed  mean  median      stdev   max   min  \
# 0      2000        20     69.299282  12.0    14.0   8.432740  24.0   0.0
# 1      4000        40    149.999950   3.9     5.5   7.264067  15.0  -7.0
# 2      6000        60    224.405275   2.0     6.0  10.583005  16.0 -20.0
# 3      8000        80    310.907154   2.8     0.5   5.808040  11.0  -5.0
# 4     10000       100    390.955571   1.0     0.5   4.760952   9.0  -5.0
# 5     12000       120    473.286106  -3.1    -1.0   5.486347   2.0 -14.0
# 6     14000       140    552.654171  -1.3    -1.0   4.448470   6.0  -9.0
# 7     16000       160    631.119376   1.0    -3.0  11.897712  22.0 -12.0
# 8     18000       180    715.875009  -3.6     0.0  12.357634  16.0 -24.0
# 9     20000       200    791.129390   7.6     9.0  12.571573  28.0 -20.0
# 10    22000       220    865.907663   9.0    12.0  11.284207  20.0 -16.0
# 11    24000       240    946.217469  -9.0    -5.0  12.119773   6.0 -36.0
# 12    26000       260   1027.073628   1.2     0.5   5.788878  14.0  -6.0
# 13    28000       280   1105.170291  -3.2    -1.0  15.295606  20.0 -30.0
# 14    30000       300   1185.275775   0.0     0.0   0.000000   0.0   0.0
# 15    32000       320   1263.305903  -1.2    -4.0  16.497811  34.0 -18.0
# 16    34000       340   1341.633422  -4.7    -4.0   4.877385   5.0 -12.0
# 17    36000       360   1419.832661   7.4    10.0  10.751744  28.0  -6.0
# 18    38000       380   1498.597879   7.0     7.0  15.297059  32.0 -20.0
# 19    40000       400   1574.952105   6.0     6.0   9.933110  22.0  -8.0
# 20    42000       420   1647.870751  -1.8    -2.0   8.403703  10.0 -18.0
# 21    44000       440   1720.982319   8.6    12.0  13.599020  28.0 -14.0
# 22    46000       460   1799.354293   4.8     5.0  16.443844  40.0 -22.0
# 23    48000       480   1873.923517  -1.4    -2.0  11.625642  14.0 -22.0
# 24    50000       500   1948.251150  -1.0    -3.0   9.718253  16.0 -14.0
# 25    52000       520   2023.019607   2.6     2.0  12.258331  30.0 -16.0
# 26    54000       540   2098.070011  -6.0    -4.0   9.521905   6.0 -20.0
# 27    56000       560   2169.970301  -3.0    -1.5   6.110101   7.0 -13.0
# 28    58000       580   2241.212604   7.6     8.0  13.977760  34.0 -16.0
# 29    60000       600   2313.167013  -2.0    -4.0  11.430952  16.0 -18.0
# ..      ...       ...           ...   ...     ...        ...   ...   ...
# 174  350000      3500  13655.469767   5.0     5.0  10.033278  20.0  -8.0
# 14    0.031948      0.280474
# 15    0.029790      0.287332
# 16    0.011100      0.289834
# 17    0.073643      0.291061
# 18    0.039954      0.296136
# 19    0.052576      0.296256
# 20    0.112887      0.300175
# 21    0.145450      0.302173
# 22    0.128385      0.306834
# 23    0.154172      0.306921
# 24    0.073082      0.312121
# 25    0.131592      0.312595
# 26    0.117360      0.320223
# 27    0.117245      0.316324
# 28    0.128869      0.318839
# 29    0.041786      0.321688
# ..         ...           ...
# 174   0.757154      0.359265
# 175   0.780305      0.358106
# 176   0.794007      0.354455
# 177   0.792294      0.355544
# 178   0.782635      0.353871
# 179   0.762311      0.357087
# 180   0.828669      0.354594
# 181   0.796980      0.355908
# 182   0.809017      0.359218
# 183   0.784384      0.356160
# 184   0.764626      0.360145
# 185   0.814922      0.358244
# 186   0.830925      0.354735
# 187   0.773228      0.361415
# 188   0.775840      0.356459
# 189   0.827286      0.354947
# 190   0.785331      0.358440
# 191   0.813520      0.360452
# 192   0.848960      0.361684
# 193   0.949415      0.359110
# 194   0.848718      0.359766
# 195   0.857357      0.358689
# 196   0.864850      0.358442
# 197   0.892824      0.359265
# 198   0.863587      0.353965
# 199   0.911149      0.356036
# 200   0.947476      0.362236
# 201   0.972647      0.352318
# 202   0.955503      0.355825
# 203   0.817824      0.357148
#
# [204 rows x 10 columns]

# %%
data['mean'].tail(300).rolling(10).mean().plot(figsize=(15, 5))

# %%
data['average_loss'].plot(figsize=(15, 5), logy=True)

# %%
data.average_q.plot(figsize=(15, 5))

# %%
data['mean'].cumsum().plot()

# %%
data.stdev.rolling(10).mean().plot()

# %%
data['median'].rolling(10).median().plot()

# %%
data['min'].rolling(10).mean().plot()

# %%
data['max'].rolling(10).mean().plot()

# %%
data['mean'].tail(300).rolling(10).mean().plot(figsize=(15, 5))

# %%
# result_4
data['mean'].tail(300).rolling(10).mean().plot(figsize=(15, 5))

# %%
from chainer import cuda

# %%
dev0 = cuda.get_device_from_id(0)
dev1 = cuda.get_device_from_id(1)
dev0, dev1
# Out:
# (<CUDA Device 0>, <CUDA Device 1>)

# %%
dev0.compute_capability
# Out:
# '61'

# %%
dev1.compute_capability
# Out:
# '30'

# %%
import chainer, chainerrl

# %%
import cupy
import numpy as np

# %%
with cupy.cuda.Device(1):
    data = np.random.randn(1000, 2).astype(np.float32)
    data *= data
data
# Out:
# array([[ 0.591506  ,  0.00536375],
#        [ 0.03556368,  3.05909586],
#        [ 0.84524459,  0.06452242],
#        ...,
#        [ 0.24711049,  0.27141607],
#        [ 0.01210455,  0.09006582],
#        [ 4.75340128,  0.88345915]], dtype=float32)
